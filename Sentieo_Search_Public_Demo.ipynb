# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-sentieo/sentieo-public-api-examples/blob/master/Sentieo_Search_Public_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Search API Public Demo
# In this Collab Doc, we will show you how to use the search api. First we cover the basic features. Then we provide specific examples for edgar filings and notes to demonstrate more advanced features. Then we demonstrate some common errors and how to handle them.
#
# For each block of code read the text above the block and then run the code. This first block of code sets up your notebook environment. Go ahead and run it.

# %%
# !pip install ipywidgets 
# !jupyter nbextension enable --py widgetsnbextension
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %% [markdown]
# ### API CODE
#
# This is the code which makes all the requests to the Sentieo API. It is structured like a class with functions for different functions. This does not have all the apis but only those required for this use case. Feel free to copy this class and the model directly into your code or to contribute here by adding more apis.
#
# Please fill in your own Api Key and Email at the top and run the block.

# %%
from typing import NamedTuple, List, Mapping
from datetime import date
import requests, json
from enum import Enum
import time

APIKEY = 'YJgvtmHEWY39vxITA2fDW8cdrH6s4Epz9bYvlACE'
BASE_URL = 'https://api.sentieo.com/v1'
EMAIL = 'your@email.com'
default_headers = {
                  'x-api-key': APIKEY
                }

subtypes_map = json.loads(requests.request('GET','https://raw.githubusercontent.com/mohit-sentieo/sentieo-public-api-examples/master/subtypes.json').text)

class DocTypeEnum(Enum):
  EDGARFILINGS = 'ef'
  PRESENTATIONS = 'ppt'
  PRESS_RELEASES = 'ni'
  NEWS = 'nw'
  SD = 'sd'
  GLOBAL_FILINGS = 'gbf'
  BROKER_RESEARCH = 'rr'
  TRANSCRIPTS = 'tt'
  NOTES = 'note'

  @classmethod
  def get_type_names(cls):
    return [ m.name for m in cls.__members__.values() ]
  
  def get_subtypes(self):  
    return [ v for va in subtypes_map[self.value].values() for v in va  ]
    


class SearchParams(NamedTuple):
  size:int = 20
  start:int = 0
  tickers:List[str] = []
  use_synonyms:bool = False
  query:str = ''
  date_from:date = None
  date_to:date = None
  doc_type:List[DocTypeEnum] = []
  doc_type_filters:Mapping[DocTypeEnum,Mapping[str,List[str]]] = {}
  sectors:List[str] = []
  subsectors:Mapping[str,List[str]] = {}


class SentieoAPI:
  def __init__(self, debug=True):
    self.debug = debug

  def throttled_request(self, *args, **kwargs):
    response = requests.request(*args, **kwargs)
    if response.status_code == 429:
      time.sleep(0.2)
      response = requests.request(*args, **kwargs)
    return response

  def _make_post_api_call(self, url, payload=None, headers=None):
    payload = {} if payload is None else payload
    headers = { 'Content-Type': 'application/json' } if headers == None else headers
    headers.update(default_headers)
    response = self.throttled_request("POST", BASE_URL + url, headers=headers, data = json.dumps(payload))
    if self.debug:
      print(url, response.status_code)
    return response.status_code, response.json()
  
  def _make_get_api_call(self, url, params=None, headers=None):
    params = {} if params is None else params
    headers = { } if headers == None else headers
    headers.update(default_headers)
    response = self.throttled_request("GET", BASE_URL + url, headers=headers, params = params)
    if self.debug:
      print(url, response.status_code)
    return response.status_code, response.text

  def fetch_docs_from_search(self, filters:SearchParams=None):
    #date_range_from.value.strftime("%d-%b-%Y")
    filters = filters._asdict()
    if filters['date_from'] is not None:
      filters['date_range_from'] = filters['date_from'].strftime("%d-%b-%Y")
      del filters['date_from']
    
    if filters['date_to'] is not None:
      filters['date_range_to'] = filters['date_to'].strftime("%d-%b-%Y")
      del filters['date_to']

    doc_type_list = []
    for dt in filters['doc_type']:
      if dt in filters['doc_type_filters']:
        doc_type_list.append({'name': dt.value, **filters['doc_type_filters'][dt]  })
      else:
        doc_type_list.append(dt.value)

    filters['doc_type'] = doc_type_list
    del filters['doc_type_filters']

    sector_list = []
    for sc in filters['sectors']:
      if sc in filters['subsectors']:
        sector_list.append({'name': sc, 'subsectors': filters['subsectors'][sc]  })
      else:
        sector_list.append(sc)
    del filters['subsectors']
    filters['sectors'] =  sector_list

    if self.debug:
      print(filters)
    status, result = self._make_post_api_call('/documents/search', filters)
    return result
  
  def fetch_doc_content(self, doc_id):
    status, result = self._make_get_api_call('/documents/get', { 'id': doc_id })
    return result
  
  def fetch_doc_hits(self, doc_id, query, use_synonyms='false'):
    status, result = self._make_get_api_call('/documents/hits', {'query': query, 'doc_id': doc_id, 'use_synonyms': use_synonyms })
    return json.loads(result)

sAPI = SentieoAPI()

# %% [markdown]
# ### UI CODE
# This code is only for demo purposes. It handles the UI which is rendered below.
#
# In a typical scenario, you will have your own UI built using Javascript which will send requests to your server. You server will then communicate with sentieo API. But since we cannot have that in a notebook, we have created a very simple UI in python itself. You might want to look at the submit_callback function which takes values from the UI and calls the sentieo API class.
#
# Run this code and UI will render. You can then interact with the UI. To refresh the UI, run this code again.

# %%
tickers_ui = widgets.Text(
    value='msft, aapl',
    placeholder='Tickers seperated by commas',
    description='Tickers',
    disabled=False
)
start_ui = widgets.BoundedIntText(
    value=10,
    min=0,
    max=10,
    step=1,
    description='Skip docs',
    disabled=False
)
size_ui = widgets.BoundedIntText(
    value=10,
    min=0,
    max=2000,
    step=1,
    description='Total Docs',
    disabled=False
)
synonyms_ui = widgets.Checkbox(
    value=False,
    description='USE SYNONYMS',
    disabled=False,
    indent=False
)
sort_ui = widgets.Dropdown(
    options=['filing_date:desc' ,'filing_date:asc', 'score:desc', 'score:asc'],
    value='filing_date:desc',
    description='Order By',
    disabled=False,
)
query_ui = widgets.Text(
    value='',
    placeholder='in:title sales',
    description='Query',
    disabled=False
)
doc_type_ui = widgets.SelectMultiple(
    options=DocTypeEnum.get_type_names(),
    #rows=10,
    description='document types',
    disabled=False
)
doc_subtype_ui = widgets.SelectMultiple(
    options=[],
    description='Subtypes',
    disabled=True
)
date_to_ui = widgets.DatePicker(
    description='End Date',
    disabled=False
)
date_from_ui = widgets.DatePicker(
    description='Start Date',
    disabled=False
)

submit_button = widgets.Button(
    description='Fetch Documents',
    disabled=False,
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
)

doc_id_ui = widgets.Text(
    value='',
    placeholder='4ejak2njfi',
    continuous_update=False,
    description='Enter a Doc Id to load',
    disabled=False,
    layout={"width": "300px", "margin": "50px"}
)


output_html = widgets.Output(layout={'border': '1px solid black'})

document_html = widgets.Output(layout={'border': '1px solid black'})
document_html.layout.height = '500px'

def doc_id_handler(change):
  if change['name'] == 'value' and len(change['new']) > 23 :
    document_html.clear_output(wait=True)
    doc_html = sAPI.fetch_doc_content(change['new'])
    doc_html = '<div style="background:white;font-color:black;">' + doc_html + '</div>'
    with document_html:
      display(widgets.HTML(value=doc_html.replace("class=\"t ", "class=\" ")))

def doc_subtype_handler(change):
  if change['name'] == 'value' and len(change['new']) > 0:
    doc_subtype_ui.options = [ st['label'] + ' : ' + str(st['value']) for st in DocTypeEnum[change['new'][0]].get_subtypes() ]
    doc_subtype_ui.description = change['new'][0]
    doc_subtype_ui.disabled = False
    

def build_form_ui():
  date_layout = widgets.HBox([date_from_ui, date_to_ui])
  text_layout = widgets.HBox([query_ui, tickers_ui])
  synonyms_layout = widgets.HBox([synonyms_ui, sort_ui])
  size_layout = widgets.HBox([start_ui, size_ui])
  doc_type_layout = widgets.HBox([doc_type_ui,doc_subtype_ui])
  doc_type_ui.observe(doc_subtype_handler)
  display(widgets.VBox([text_layout, date_layout, synonyms_layout, size_layout, doc_type_layout, submit_button]))

def doc_to_html(doc):
  return "<div style=\"border: 2px solid #888; padding: 5px; margin:5px;max-width: 300px\"><h4>{title}</h4><p>#{doc_id}</p><p> {ticker}, {country} </p> <p>{doc_subtype}, {doc_type}</p></div>".format(**doc)

def html_separator():
  return "<br><br>"

def enclose_doc_list(html):
  return '<div style="width:300px;height:600px;overflow:scroll;margin:100px;background:white;">' + html + '</div>'

def submit_callback(event):
  output_html.clear_output(wait=True)
  doc_type = [ DocTypeEnum[dt] for dt in doc_type_ui.value ] 
  searchparam = SearchParams(tickers=tickers_ui.value.strip().split(","), query=query_ui.value, start=start_ui.value, size=size_ui.value, date_from=date_from_ui.value, date_to=date_to_ui.value, doc_type=doc_type, use_synonyms=synonyms_ui.value)
  docs = sAPI.fetch_docs_from_search(searchparam)
  doc_list_html = html_separator().join([ doc_to_html(doc) for doc in docs['result']['docs'] ])
  final_html = enclose_doc_list(doc_list_html)
  html_widget = widgets.HTML(
      value=final_html
  )
  html_widget.layout.height = "400px"
  html_widget.layout.background = "white"
  with output_html:
    display(html_widget)
  if len(docs['result']['docs']) > 0:
    doc_id_ui.value = docs['result']['docs'][0]['doc_id']

submit_button.on_click(submit_callback)
build_form_ui()
display(doc_id_ui)
doc_id_ui.observe(doc_id_handler)
display(widgets.HBox([ output_html, document_html ]))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 60
# VBox(children=(HBox(children=(Text(value='', description='Query', placeholder='in:title sales'), Text(value='m…
# Text(value='', continuous_update=False, description='Enter a Doc Id to load', layout=Layout(margin='50px', wid…
# HBox(children=(Output(layout=Layout(border='1px solid black')), Output(layout=Layout(border='1px solid black',…

# %% [markdown]
# ### Note Search & Edgar Filings
# This section goes into some advanced use cases for edgar filing and notes.
# We will cover, how to make requests for particular edgar filings as well as how to filter by note authors, categories etc.
#
# - How to search for specific document types
# - How to search by Note Authors, Note Topics, Note Origin and Note Type
# - How to search by Broker Source and Research Report Style and Reasons
# - How to search for subsectors

# %%
def search_for_10k_and_10q():
  doc_type_filters = { DocTypeEnum.EDGARFILINGS: { 'subtypes': ['10-k', '10-q' ]} }
  params = SearchParams(doc_type=[ DocTypeEnum.EDGARFILINGS ], doc_type_filters=doc_type_filters,size=100)
  result = sAPI.fetch_docs_from_search(params)
  return result

def search_for_notes():
  doc_type_filters = { DocTypeEnum.NOTES: { 'subtypes': ['typed', 'attachment'], 'authors': [ 'mohit.kumar' ], 'categories': [ 'General' ], 'tags': [ 'cs', 'sales'] } }
  params = SearchParams(doc_type=[ DocTypeEnum.NOTES ], doc_type_filters=doc_type_filters)
  result = sAPI.fetch_docs_from_search(params)
  return result

def search_broker_research():
  doc_type_filters = { DocTypeEnum.BROKER_RESEARCH: { 'ctbids': [ 'se_11097', 'se_11835' ],'reasons': ['rr_reasons_3'], 'styles': [ 'mohit.kumar' ], 'categories': [ 'General' ], 'tags': [ 'cs', 'sales'] } }
  params = SearchParams(doc_type=[ DocTypeEnum.BROKER_RESEARCH ], doc_type_filters=doc_type_filters)
  result = sAPI.fetch_docs_from_search(params)
  return result

def search_by_subsectors():
  subsectors = { 'Health Care': ['Hospital'] }
  params = SearchParams(sectors=[ 'Health Care' ], subsectors=subsectors, tickers=['msft'])
  result = sAPI.fetch_docs_from_search(params)
  return result

kandqdocs = search_for_10k_and_10q()
# Out:
# OrderedDict([('size', 100), ('start', 0), ('tickers', []), ('use_synonyms', False), ('query', ''), ('date_from', None), ('date_to', None), ('doc_type', [{'name': 'ef', 'subtypes': ['10-k', '10-q']}]), ('sectors', [])])
# /documents/search 200

# %%
kandqdocs
# Out:
# {'response': {'msg': ['Success'], 'status': True},
#  'result': {'doc_subtype': ['10-k', '10-q'],
#   'doc_type': ['ef'],
#   'docs': [{'company_name': 'ALTAIR INTERNATIONAL CORP.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec806f10972a46f2445769b',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T17:07:12',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 19,
#     'subsectors': ['Other'],
#     'ticker': 'atao',
#     'tickers': ['atao'],
#     'title': '10-K FY 2019'},
#    {'company_name': 'QuickLogic Corporation',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec8044a0972a46f2cc4f35b',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T16:55:28',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 39,
#     'subsectors': ['Semiconductors'],
#     'ticker': 'quik',
#     'tickers': ['quik', 'qkl:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Chun Can Capital Group',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec803b30972a46f160dbc9d',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T16:53:09',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 10,
#     'subsectors': ['Other'],
#     'ticker': 'cncn',
#     'tickers': ['cncn'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Dream Homes & Development Corp.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7e17e5133ce6afa39ee23',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T14:26:19',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 54,
#     'subsectors': ['Other'],
#     'ticker': 'drem',
#     'tickers': ['drem'],
#     'title': '10-K FY 2019'},
#    {'company_name': 'Rhino Resource Partners LP',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7d8f20972a46f2cc4f309',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T13:50:33',
#     'is_pdf_doc': False,
#     'sectors': ['Energy'],
#     'size': 82,
#     'subsectors': ['Coal & Consumable Fuels'],
#     'ticker': 'rhno',
#     'tickers': ['rhno', '90r:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'McKesson Corporation',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7c87e0972a46f24457630',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T12:38:58',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 298,
#     'subsectors': ['Health Care Distributors'],
#     'ticker': 'mck',
#     'tickers': ['mck', 'mck:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': "CHUY'S HOLDINGS, INC.",
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7bfa50972a46f1572fe83',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T12:02:55',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 32,
#     'subsectors': ['Restaurants'],
#     'ticker': 'chuy',
#     'tickers': ['chuy', 'cuy:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'TYME TECHNOLOGIES, INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7b8945133ce6bd78a64df',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T11:31:37',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 228,
#     'subsectors': ['Biotechnology'],
#     'ticker': 'tyme',
#     'tickers': ['tyme', 'rfl:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'Keros Therapeutics, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7b4e50972a46f160dbc51',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T11:16:37',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 125,
#     'subsectors': ['Other'],
#     'ticker': 'kros',
#     'tickers': ['kros'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Allegiant Travel CO',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a3d10972a46f160dbc3f',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T01:54:14',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 107,
#     'subsectors': ['Airlines'],
#     'ticker': 'algt',
#     'tickers': ['algt', 'agh:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'MICROCHIP TECHNOLOGY INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a38f0972a46f24457600',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T01:08:01',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 157,
#     'subsectors': ['Semiconductors'],
#     'ticker': 'mchp',
#     'tickers': ['mchp', 'micr:sw', 'mchp:av', 'mcp:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'International Land Alliance Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a38f5133ce6afa39ede0',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T01:06:57',
#     'is_pdf_doc': False,
#     'sectors': ['Real Estate'],
#     'size': 28,
#     'subsectors': ['Real Estate Development'],
#     'ticker': 'ilal',
#     'tickers': ['ilal'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Taronis Fuels, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a38f0972a46f274f1de5',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-22T00:13:02',
#     'is_pdf_doc': False,
#     'sectors': ['Materials'],
#     'size': 99,
#     'subsectors': ['Industrial Gases'],
#     'ticker': 'trnf',
#     'tickers': ['trnf'],
#     'title': '10-K FY 2019'},
#    {'company_name': 'KBS Strategic Opportunity REIT, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a3485133ce6afa39eddd',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T23:13:46',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 74,
#     'subsectors': ['Other'],
#     'ticker': 'kbsstrategic:pvt',
#     'tickers': ['kbsstrategic:pvt'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Palo Alto Networks Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a3035133ce6afa39edd4',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T23:12:35',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 116,
#     'subsectors': ['Systems Software'],
#     'ticker': 'panw',
#     'tickers': ['panw', '5ap:gr'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'EPLUS INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a3925133ce6b05b6275f',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T22:05:48',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 118,
#     'subsectors': ['Technology Distributors'],
#     'ticker': 'plus',
#     'tickers': ['plus', 'mle:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'CHARLES & COLVARD LTD',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec7a3d20972a46f24457606',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T22:01:05',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 55,
#     'subsectors': ['Apparel, Accessories & Luxury Goods'],
#     'ticker': 'cthr',
#     'tickers': ['cthr', 'cthr:gr', 'cdr:gr'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'ORANCO INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6ef940972a46f274f1db1',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T21:13:58',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 31,
#     'subsectors': ['Distributors'],
#     'ticker': 'ornc',
#     'tickers': ['ornc'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'Haverty Furniture Companies, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6ecfd0972a46f160dbc00',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T21:03:36',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 21,
#     'subsectors': ['Homefurnishing Retail'],
#     'ticker': 'hvt',
#     'tickers': ['hvt', 'hvt.a', '25f:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Hyster-Yale Materials Handling Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6ecfe0972a46f274f1d98',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T21:03:00',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 37,
#     'subsectors': ['Industrial Machinery'],
#     'ticker': 'hy',
#     'tickers': ['hy', 'hyea:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'H-CYTE, INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6ec680972a46f2cc4f299',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T21:00:43',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care', 'Other'],
#     'size': 41,
#     'subsectors': ['Other', 'Health Care Equipment'],
#     'ticker': 'hcyt',
#     'tickers': ['hcyt', 'mdvxw'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'DYCOM INDUSTRIES INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6ebd10972a46f160dbbee',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:57:53',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 57,
#     'subsectors': ['Construction & Engineering'],
#     'ticker': 'dy',
#     'tickers': ['dy', 'dyi:gr'],
#     'title': '10-Q FY21 Q1'},
#    {'company_name': 'Xenon Pharmaceuticals Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e9295133ce6b05b62711',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:47:09',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 96,
#     'subsectors': ['Biotechnology'],
#     'ticker': 'xene',
#     'tickers': ['xene', 'xp0:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Skyline Champion Corp',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e8925133ce6afa39ed84',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:44:31',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 211,
#     'subsectors': ['Homebuilding'],
#     'ticker': 'sky',
#     'tickers': ['sky'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'Synchronoss Technologies, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e7b20972a46f274f1d77',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:40:41',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 50,
#     'subsectors': ['Application Software'],
#     'ticker': 'sncr',
#     'tickers': ['sncr', 'h6k:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Ellington Financial Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e6d50972a46f274f1d6b',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:36:17',
#     'is_pdf_doc': False,
#     'sectors': ['Financials'],
#     'size': 140,
#     'subsectors': ['Mortgage REITs'],
#     'ticker': 'efc',
#     'tickers': ['efc'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'NVIDIA CORP',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e5ec0972a46f274f1d5a',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:32:58',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 76,
#     'subsectors': ['Semiconductors'],
#     'ticker': 'nvda',
#     'tickers': ['nvda', 'nvda:sw', 'nvd:gr', 'nvda:av'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Intuit Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e3455133ce6b05b626e5',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:22:09',
#     'is_pdf_doc': False,
#     'sectors': ['Other', 'Information Technology'],
#     'size': 74,
#     'subsectors': ['Other', 'Application Software'],
#     'ticker': 'intu',
#     'tickers': ['intu', 'intu:av', 'intu:sw', 'intu34:bz', 'itu:gr'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'PENNSYLVANIA REAL ESTATE INVESTMENT TRUST',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e2145133ce6afa39ed2d',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:17:08',
#     'is_pdf_doc': False,
#     'sectors': ['Real Estate'],
#     'size': 91,
#     'subsectors': ['Retail REITs'],
#     'ticker': 'pei',
#     'tickers': ['pei', 'wx3:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Lifetime Brands Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e17d0972a46f160dbb91',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:14:13',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 55,
#     'subsectors': ['Housewares & Specialties'],
#     'ticker': 'lcut',
#     'tickers': ['lcut', 'lh1:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': "Bloomin' Brands, Inc.",
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e0040972a46f24457572',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:08:35',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 59,
#     'subsectors': ['Restaurants'],
#     'ticker': 'blmn',
#     'tickers': ['blmn', 'boo:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'ABIOMED INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6e0390972a46f274f1d0e',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:08:19',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 165,
#     'subsectors': ['Health Care Equipment'],
#     'ticker': 'abmd',
#     'tickers': ['abmd', 'aio:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'Applied Materials, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6dfbb5133ce6b05b626bd',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T20:06:27',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 78,
#     'subsectors': ['Semiconductor Equipment'],
#     'ticker': 'amat',
#     'tickers': ['amat', '4336:hk', 'amat:av', 'amat:sw', 'ap2:gr'],
#     'title': '10-Q FY20 Q2'},
#    {'company_name': 'Duke Mountain Resources Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6d9635133ce6b05b6269c',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T19:38:32',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 11,
#     'subsectors': ['Other'],
#     'ticker': 'dkmr',
#     'tickers': ['dkmr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Exceed World, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6c78e0972a46f160dbb35',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T18:23:38',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 22,
#     'subsectors': ['Other'],
#     'ticker': 'exdw',
#     'tickers': ['exdw'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Therapeutic Solutions International Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6b9f90972a46f274f1cc5',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T17:25:16',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 58,
#     'subsectors': ['Other'],
#     'ticker': 'tsoi',
#     'tickers': ['tsoi'],
#     'title': '10-K FY 2019'},
#    {'company_name': 'TJX Companies Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6b7520972a46f274f1cbf',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T17:14:10',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary', 'Other'],
#     'size': 40,
#     'subsectors': ['Other', 'Apparel Retail'],
#     'ticker': 'tjx',
#     'tickers': ['tjx', 'tjx:gr', 'tjxc34:bz'],
#     'title': '10-Q FY21 Q1'},
#    {'company_name': 'Select Interior Concepts, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6ac215133ce6bd78a63e1',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T16:26:55',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 60,
#     'subsectors': ['Specialized Consumer Services'],
#     'ticker': 'sic',
#     'tickers': ['sic'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'SUPERIOR ENERGY SERVICES INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6a1a25133ce6afa39ecc1',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T15:42:11',
#     'is_pdf_doc': False,
#     'sectors': ['Energy'],
#     'size': 38,
#     'subsectors': ['Oil & Gas Equipment & Services'],
#     'ticker': 'spn',
#     'tickers': ['spn', 'sjr:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'U.S. Physical Therapy, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6902c0972a46f24457502',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T14:27:04',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 52,
#     'subsectors': ['Health Care Facilities'],
#     'ticker': 'usph',
#     'tickers': ['usph', 'uph:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Trio-Tech International',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec683360972a46f2cc4f1df',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T13:32:13',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 55,
#     'subsectors': ['Semiconductor Equipment'],
#     'ticker': 'trt',
#     'tickers': ['trt'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'ROYAL CARIBBEAN CRUISES LTD',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec67d030972a46f274f1c8b',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T13:05:32',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 497,
#     'subsectors': ['Hotels, Resorts & Cruise Lines'],
#     'ticker': 'rcl',
#     'tickers': ['rcl', 'roc:ss', 'rcl:no', 'rc8:gr', 'rclc:sw'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'BRADY CORP',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec663ad0972a46f160dbab9',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T11:17:29',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 34,
#     'subsectors': ['Commercial Printing'],
#     'ticker': 'brc',
#     'tickers': ['brc', 'brv:gr'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'APOLLO INVESTMENT CORP',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec65fd75133ce6b05b6262f',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-21T11:01:01',
#     'is_pdf_doc': False,
#     'sectors': ['Other', 'Financials'],
#     'size': 237,
#     'subsectors': ['Mortgage REITs',
#      'Other',
#      'Asset Management & Custody Banks'],
#     'ticker': 'aib',
#     'tickers': ['aib', '55o1:gr', 'ainv', 'aiy'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'CorePoint Lodging Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec652560972a46f274f1c4d',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T22:15:40',
#     'is_pdf_doc': False,
#     'sectors': ['Energy', 'Real Estate'],
#     'size': 266,
#     'subsectors': ['Oil & Gas Exploration & Production',
#      'Hotel & Resort REITs'],
#     'ticker': 'cplg',
#     'tickers': ['cplg', 'wzr:cn', '44w:gr', 'wzgrf-old'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Expedia Group, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec6520f0972a46f274f1c41',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:43:39',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary', 'Other'],
#     'size': 84,
#     'subsectors': ['Other', 'Internet & Direct Marketing Retail'],
#     'ticker': 'expe',
#     'tickers': ['expe', 'exgr34:bz', 'expe:av', 'expe:sw', 'e3x1:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'NightFood Hldg Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5a1690972a46f274f1c10',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:28:33',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 40,
#     'subsectors': ['Other'],
#     'ticker': 'ngtf',
#     'tickers': ['ngtf'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'hopTo Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5a0d00972a46f274f1c02',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:26:50',
#     'is_pdf_doc': False,
#     'sectors': ['Other', 'Information Technology'],
#     'size': 15,
#     'subsectors': ['Other', 'Application Software'],
#     'ticker': 'hpto',
#     'tickers': ['hpto', 'gpn:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Blow & Drive Interlock Corp',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5a0d25133ce6b05b625df',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:26:19',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 42,
#     'subsectors': ['Other'],
#     'ticker': 'bdic',
#     'tickers': ['bdic'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'ARVANA INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5a0860972a46f274f1bfe',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:25:07',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 15,
#     'subsectors': ['Other'],
#     'ticker': 'avni',
#     'tickers': ['avni'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Manhattan Scientifics Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec59e760972a46f24457476',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:15:48',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 26,
#     'subsectors': ['Biotechnology'],
#     'ticker': 'mhtx',
#     'tickers': ['mhtx'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Sequential Brands Group, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec59b820972a46f24457464',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T21:03:36',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 71,
#     'subsectors': ['Apparel, Accessories & Luxury Goods'],
#     'ticker': 'sqbg',
#     'tickers': ['sqbg', 'sqb:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Qorvo, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec599d45133ce6afa39ec28',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:55:15',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 120,
#     'subsectors': ['Semiconductors'],
#     'ticker': 'qrvo',
#     'tickers': ['qrvo', '2qo:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'RespireRx Pharmaceuticals Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec599275133ce6b05b625a2',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:53:50',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 70,
#     'subsectors': ['Pharmaceuticals'],
#     'ticker': 'rspi',
#     'tickers': ['rspi'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Gulf Resources, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec597b05133ce6afa39ec1f',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:46:44',
#     'is_pdf_doc': False,
#     'sectors': ['Materials'],
#     'size': 37,
#     'subsectors': ['Commodity Chemicals'],
#     'ticker': 'gure',
#     'tickers': ['gure', 'r29a:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'NeuroBo Pharmaceuticals, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec597630972a46f274f1bd0',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:46:38',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 41,
#     'subsectors': ['Biotechnology'],
#     'ticker': 'nrbo',
#     'tickers': ['nrbo'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Quad M Solutions, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec596350972a46f1572fc64',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:40:49',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 34,
#     'subsectors': ['Other'],
#     'ticker': 'mmmm',
#     'tickers': ['mmmm'],
#     'title': '10-Q FY20 Q2'},
#    {'company_name': 'Sun Pacific Holding Corp.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec595a10972a46f1572fc57',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:38:53',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 68,
#     'subsectors': ['Other'],
#     'ticker': 'snpw',
#     'tickers': ['snpw'],
#     'title': '10-K FY 2019'},
#    {'company_name': 'ELECTRONIC ARTS INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec595550972a46f2cc4f159',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:37:16',
#     'is_pdf_doc': False,
#     'sectors': ['Communication Services'],
#     'size': 131,
#     'subsectors': ['Interactive Home Entertainment'],
#     'ticker': 'ea',
#     'tickers': ['ea', 'ea:av', 'ert:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'ORIC Pharmaceuticals Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec593db5133ce6bd78a62e6',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:31:28',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 120,
#     'subsectors': ['Biotechnology'],
#     'ticker': 'oric',
#     'tickers': ['oric'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'AMERICAN CRYOSTEM Corp',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec593e95133ce6bd78a62e9',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:31:25',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 48,
#     'subsectors': ['Biotechnology'],
#     'ticker': 'cryo',
#     'tickers': ['cryo'],
#     'title': '10-Q FY20 Q2'},
#    {'company_name': 'Haemonetics Corporation',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec593dc0972a46f24457437',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:30:48',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 128,
#     'subsectors': ['Health Care Supplies'],
#     'ticker': 'hae',
#     'tickers': ['hae', 'haz:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'Hawkins, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec592610972a46f160db9ff',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:24:02',
#     'is_pdf_doc': False,
#     'sectors': ['Materials'],
#     'size': 79,
#     'subsectors': ['Commodity Chemicals'],
#     'ticker': 'hwkn',
#     'tickers': ['hwkn', 'hwk:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'GLOBAL DIGITAL SOLUTIONS INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec592155133ce6afa39ebec',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:23:00',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 57,
#     'subsectors': ['Aerospace & Defense'],
#     'ticker': 'gdsi',
#     'tickers': ['gdsi'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Can B Corp',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec591de0972a46f1572fc3c',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:22:47',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 28,
#     'subsectors': ['Pharmaceuticals'],
#     'ticker': 'canb',
#     'tickers': ['canb'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'ACQUIRED SALES CORP',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5917d5133ce6bd78a62d6',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:20:56',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 62,
#     'subsectors': ['Other'],
#     'ticker': 'aqsp',
#     'tickers': ['aqsp'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'NetScout Systems, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec591325133ce6afa39ebe6',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:19:20',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 146,
#     'subsectors': ['Communications Equipment'],
#     'ticker': 'ntct',
#     'tickers': ['ntct', 'nsz:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'RBC Bearings INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5909d0972a46f2cc4f137',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:16:42',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 97,
#     'subsectors': ['Industrial Machinery'],
#     'ticker': 'roll',
#     'tickers': ['roll', 'b1x:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'NTN Buzztime Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5909d5133ce6b05b62577',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:16:25',
#     'is_pdf_doc': False,
#     'sectors': ['Communication Services'],
#     'size': 52,
#     'subsectors': ['Movies & Entertainment'],
#     'ticker': 'ntn',
#     'tickers': ['ntn'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Regenicin, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5904e0972a46f1572fc20',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:16:04',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 18,
#     'subsectors': ['Other'],
#     'ticker': 'rgin',
#     'tickers': ['rgin'],
#     'title': '10-Q FY20 Q2'},
#    {'company_name': 'WORLD HEALTH ENERGY HOLDINGS, INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58f6d5133ce6afa39ebc6',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:12:12',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 13,
#     'subsectors': ['Application Software'],
#     'ticker': 'when',
#     'tickers': ['when'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'NanoVibronix Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58f220972a46f1572fc0f',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:11:12',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 125,
#     'subsectors': ['Health Care Equipment'],
#     'ticker': 'naov',
#     'tickers': ['naov'],
#     'title': '10-K FY 2019'},
#    {'company_name': 'Kelinda',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58f255133ce6afa39ebc2',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:10:41',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 13,
#     'subsectors': ['Other'],
#     'ticker': 'klda',
#     'tickers': ['klda'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'Summer Energy Holdings Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58ed55133ce6bd78a62bc',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:09:45',
#     'is_pdf_doc': False,
#     'sectors': ['Utilities'],
#     'size': 47,
#     'subsectors': ['Electric Utilities'],
#     'ticker': 'sume',
#     'tickers': ['sume'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Orbital Energy Group, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58e870972a46f274f1b6a',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:08:46',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 97,
#     'subsectors': ['Electronic Equipment & Instruments'],
#     'ticker': 'oeg',
#     'tickers': ['oeg', 'cij:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'UAS Drone Corp.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58e3d0972a46f160db9d0',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:07:18',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 27,
#     'subsectors': ['Other'],
#     'ticker': 'usdr',
#     'tickers': ['usdr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'ECARD INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58e3e0972a46f1572fc08',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:06:59',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 15,
#     'subsectors': ['Other'],
#     'ticker': 'ecrd',
#     'tickers': ['ecrd'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Cirrus Logic, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58d4d0972a46f24457402',
#     'doc_subtype': '10-k',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:02:27',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 90,
#     'subsectors': ['Semiconductors'],
#     'ticker': 'crus',
#     'tickers': ['crus', 'cru:gr'],
#     'title': '10-K FY 2020'},
#    {'company_name': 'Q2Earth Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58d0f0972a46f2cc4f10f',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T20:01:35',
#     'is_pdf_doc': False,
#     'sectors': ['Materials'],
#     'size': 37,
#     'subsectors': ['Fertilizers & Agricultural Chemicals'],
#     'ticker': 'qpwr',
#     'tickers': ['qpwr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Gex Management Inc',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec58b945133ce6b05b6252f',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T19:55:27',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 20,
#     'subsectors': ['Other'],
#     'ticker': 'gxxm',
#     'tickers': ['gxxm'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'UNITED CAPITAL CONSULTANTS INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5889c0972a46f274f1b51',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T19:42:49',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 17,
#     'subsectors': ['Other'],
#     'ticker': 'unitedcapital:pvt',
#     'tickers': ['unitedcapital:pvt'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Fritzy Tech Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec583940972a46f160db9a5',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T19:22:14',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 23,
#     'subsectors': ['Other'],
#     'ticker': 'frfr',
#     'tickers': ['frfr'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'Data Storage Corp',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec57e8a0972a46f1572fbce',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:59:38',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 28,
#     'subsectors': ['IT Consulting & Other Services'],
#     'ticker': 'dtst',
#     'tickers': ['dtst'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'CLEARONE INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec578005133ce6b05b62505',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:31:46',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 24,
#     'subsectors': ['Communications Equipment'],
#     'ticker': 'clro',
#     'tickers': ['clro'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Brazil Minerals, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec575515133ce6bd78a6279',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:20:58',
#     'is_pdf_doc': False,
#     'sectors': ['Materials'],
#     'size': 27,
#     'subsectors': ['Precious Metals & Minerals'],
#     'ticker': 'bmix',
#     'tickers': ['bmix'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Professional Diversity Network, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5733a0972a46f274f1b27',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:12:19',
#     'is_pdf_doc': False,
#     'sectors': ['Communication Services'],
#     'size': 42,
#     'subsectors': ['Interactive Media & Services'],
#     'ticker': 'ipdn',
#     'tickers': ['ipdn'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Sugarmade, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec572ec5133ce6bd78a6270',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:10:55',
#     'is_pdf_doc': False,
#     'sectors': ['Materials'],
#     'size': 41,
#     'subsectors': ['Paper Products'],
#     'ticker': 'sgmd',
#     'tickers': ['sgmd'],
#     'title': '10-Q FY19 Q3'},
#    {'company_name': 'TPT GLOBAL TECH, INC.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec572545133ce6bd78a626c',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:07:49',
#     'is_pdf_doc': False,
#     'sectors': ['Communication Services'],
#     'size': 35,
#     'subsectors': ['Integrated Telecommunication Services'],
#     'ticker': 'tptw',
#     'tickers': ['tptw'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'SinglePoint Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec572085133ce6afa39eb6d',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:06:47',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 24,
#     'subsectors': ['Other'],
#     'ticker': 'sing',
#     'tickers': ['sing'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'VIVIC CORP.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec571725133ce6afa39eb63',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T18:04:06',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 23,
#     'subsectors': ['Other'],
#     'ticker': 'vivc',
#     'tickers': ['vivc'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Samson Oil & Gas LTD',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec56f3d0972a46f244573c2',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T17:54:15',
#     'is_pdf_doc': False,
#     'sectors': ['Energy'],
#     'size': 39,
#     'subsectors': ['Oil & Gas Exploration & Production'],
#     'ticker': 'ssnyy',
#     'tickers': ['ssnyy', 's6ob:gr', 's6o:gr', 'ssn:au'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'QUANTRX BIOMEDICAL CORP',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec56c3f0972a46f160db986',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T17:42:21',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 18,
#     'subsectors': ['Health Care Equipment'],
#     'ticker': 'qtxb',
#     'tickers': ['qtxb'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Banjo & Matilda, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec565690972a46f160db969',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T17:13:10',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 29,
#     'subsectors': ['Internet & Direct Marketing Retail'],
#     'ticker': 'banj',
#     'tickers': ['banj'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'Edge Data Solutions, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5618e0972a46f274f1b14',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T16:56:30',
#     'is_pdf_doc': False,
#     'sectors': ['Other'],
#     'size': 21,
#     'subsectors': ['Other'],
#     'ticker': 'edgs',
#     'tickers': ['edgs'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'INTERNATIONAL ISOTOPES INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec5605f0972a46f274f1b10',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T16:51:29',
#     'is_pdf_doc': False,
#     'sectors': ['Health Care'],
#     'size': 35,
#     'subsectors': ['Life Sciences Tools & Services'],
#     'ticker': 'inis',
#     'tickers': ['inis', 'ivw:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'MPHASE TECHNOLOGIES INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec55c390972a46f2cc4f0cc',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T16:32:50',
#     'is_pdf_doc': False,
#     'sectors': ['Industrials'],
#     'size': 42,
#     'subsectors': ['Electrical Components & Equipment'],
#     'ticker': 'xdsl',
#     'tickers': ['xdsl'],
#     'title': '10-Q FY20 Q3'},
#    {'company_name': 'Analog Devices, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec54b120972a46f274f1ae9',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T15:20:35',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 55,
#     'subsectors': ['Semiconductors'],
#     'ticker': 'adi',
#     'tickers': ['adi', 'adi:av', 'anl:gr'],
#     'title': '10-Q FY20 Q2'},
#    {'company_name': 'DIGITAL ALLY INC',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec546a10972a46f2445738b',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T15:01:31',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 49,
#     'subsectors': ['Electronic Equipment & Instruments'],
#     'ticker': 'dgly',
#     'tickers': ['dgly', '1daa:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Sypris Solutions, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec53ef40972a46f2cc4f0a3',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T14:28:42',
#     'is_pdf_doc': False,
#     'sectors': ['Consumer Discretionary'],
#     'size': 32,
#     'subsectors': ['Auto Parts & Equipment'],
#     'ticker': 'sypr',
#     'tickers': ['sypr', 'sjs:gr'],
#     'title': '10-Q FY20 Q1'},
#    {'company_name': 'Cavitation Technologies, Inc.',
#     'country': 'United States',
#     'country_code': 'us',
#     'doc_id': '5ec53b1d0972a46f2cc4f09f',
#     'doc_subtype': '10-q',
#     'doc_type': 'ef',
#     'filing_date': '2020-05-20T14:12:18',
#     'is_pdf_doc': False,
#     'sectors': ['Information Technology'],
#     'size': 23,
#     'subsectors': ['Electronic Components'],
#     'ticker': 'cvat',
#     'tickers': ['cvat', 'wtc:gr'],
#     'title': '10-Q FY20 Q3'}],
#   'total': 45296}}

# %% [markdown]
# ### Parallel Execution
# Here is a very simple multithreaded implementation. This is only for demonstration or simple use cases. Do not use this in production.

# %%
import requests
from threading import Thread
from typing import List, Mapping
import sys
import queue

class ThreadRunner:
    def __init__(self, fn_to_run, default_params):
        self.fn_to_run = fn_to_run
        self.default_params = default_params
        self.q = queue.Queue()
        self.results = []

    def doWork(self):
        while True:
            params = self.q.get()
            params = {**self.default_params, **params}
            res = self.fn_to_run(**params)
            self.results.append(res)
            self.q.task_done()

    def start(self, params_list:List[dict]) -> List[dict]:
        for i in range(len(params_list)):
            t = Thread(target=self.doWork)
            t.daemon = True
            t.start()
        try:
            for params in params_list:
                self.q.put(params)
            self.q.join()
            return self.results
        except KeyboardInterrupt:
            sys.exit(1)
    
    def reset(self):
        self.results = []

BATCH_SIZE = 5
def make_batches(lst):
    return [ lst[ i: i + BATCH_SIZE ] for i in range(0, len(lst), BATCH_SIZE) ]

doc_ids = [ { 'doc_id': d['doc_id'] }  for d in kandqdocs['result']['docs'] ]
hit_results = []
for batch in make_batches(doc_ids):
  thread_runner = ThreadRunner(fn_to_run=sAPI.fetch_doc_hits, default_params={'query': 'sales'})
  batch_results = thread_runner.start(batch)
  hit_results.append(batch_results)

# %% [markdown]
# ### Get all Docs between two dates
#
# Here is the code to get all documents between two date ranges. It splits the time interval into weeks and then gets all the docs for that week. This is done to improve pagination performance.

# %%
from datetime import timedelta
def get_all_docs_in_date_range(start_date, end_date, doctypes):
  curr_date = start_date
  total_results = []
  while curr_date < end_date:
    s = curr_date
    e = curr_date + timedelta(days=7)
    e = e if e <= end_date else end_date
    weekly_result = []
    total = 0
    start = 0 
    size = 2000
    while start <= total:
      params = SearchParams(doc_type=doctypes , size=size, start=start, date_from=s, date_to=e)
      result = sAPI.fetch_docs_from_search(params)
      weekly_result.append(result['result']['docs'])
      total = result['result']['total']
      start = start + size
    total_results = total_results + weekly_result
    curr_date = e
  return total_results

# %% [markdown]
# ### Error Handling
#
# Here we provide common errors and how to handle them. Notice the throttled 429 is already handled in the throttled request function above.

# %% [markdown]
# ### Admin Key Functionality
#
# For an organization, an admin key can be used to make requests on behalf of any user of the organization. First we show you the admin key usage. Then we will cover an edge case which comes up often, which is searching for all notes in your organization.
